# %% [markdown]
# <h2>Assignment 2</h2>

# %% [markdown]
# <h4>1.load the dataset<h4/>

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('House price india.csv')

# Display the first few rows of the dataset to inspect its structure
print(data.head())
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %% [markdown]
# <h4>Perform the Below Visualizations.
#
# Univariate Analysis,
#
# Bi-Variate Analysis
#
# Multivariate Analysis</h4>

# %%
<h5>Univariate Analysis</h5>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Univariate analysis for 'Price'
plt.figure(figsize=(8, 6))
sns.histplot(data['Price'], bins=20, kde=True)
plt.title('Distribution of Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
sns.distplot(data['number of bedrooms'])
# Out:
# C:\Users\hindu\AppData\Local\Temp\ipykernel_14248\1294723532.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['number of bedrooms'])
# <Axes: xlabel='number of bedrooms', ylabel='Density'>

# %%
sns.boxplot(data['Built Year'])
# Out:
# <Axes: >

# %%
# Bivariate analysis for 'Price' vs. 'Number of Bedrooms'
plt.figure(figsize=(8, 6))
sns.scatterplot(x='number of bedrooms', y='Price', data=data)
plt.title('Price vs. Number of Bedrooms')
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price')
plt.show()

# %%
sns.lineplot(x=df.living_area,y=df.Price)

# %% [markdown]
# <h5>Multivariate analysis</h5>

# %%
sns.pairplot(data)
# Out:
# KeyboardInterrupt
# Error in callback <function _draw_all_if_interactive at 0x0000012F4F5B53A0> (for post_execute):
# KeyboardInterrupt
# Error in callback <function flush_figures at 0x0000012F51C4A2A0> (for post_execute):
# KeyboardInterrupt

# %%
# Multivariate analysis - Correlation heatmap
correlation_matrix = data.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Descriptive statistics
desc_stats = data.describe()
print(desc_stats)
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
# Check for missing values
missing_values = data.isnull().sum()
print(missing_values)
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %% [markdown]
# no null value if it has null then if Impute missing values for numeric columns then we use median or mean for replacing null
# if Impute missing values for categorical columns then mode for replacing null
